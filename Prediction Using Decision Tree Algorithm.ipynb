# %% [markdown]
# THE SPARKS FOUNDATION
# TASK:6
# PREDICTION USING DECISION TREE ALGORITHM
# DONE BY:Sajja Bhavana

# %%
import numpy as np
import pandas as pd
iris_dataSet= pd.read_csv('Iris.csv')
iris_dataSet
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
iris_dataSet= iris_dataSet.drop(columns="Id")
iris_dataSet.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
from sklearn import preprocessing
label_encoder=preprocessing.LabelEncoder()
iris_dataSet['Species']=label_encoder.fit_transform(iris_dataSet['Species'])
iris_dataSet
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0              5.1           3.5            1.4           0.2        0
# 1              4.9           3.0            1.4           0.2        0
# 2              4.7           3.2            1.3           0.2        0
# 3              4.6           3.1            1.5           0.2        0
# 4              5.0           3.6            1.4           0.2        0
# ..             ...           ...            ...           ...      ...
# 145            6.7           3.0            5.2           2.3        2
# 146            6.3           2.5            5.0           1.9        2
# 147            6.5           3.0            5.2           2.0        2
# 148            6.2           3.4            5.4           2.3        2
# 149            5.9           3.0            5.1           1.8        2
#
# [150 rows x 5 columns]

# %%
#splitting data into dependent and independent variable
x=iris_dataSet.iloc[:,:-1]
x.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2
# 2            4.7           3.2            1.3           0.2
# 3            4.6           3.1            1.5           0.2
# 4            5.0           3.6            1.4           0.2

# %%
y=iris_dataSet.iloc[:,-1]
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Species, dtype: int32

# %%
#split the dataset for train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.33, random_state=42)

# %%
X_train.head()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 96             5.7           2.9            4.2           1.3
# 105            7.6           3.0            6.6           2.1
# 66             5.6           3.0            4.5           1.5
# 0              5.1           3.5            1.4           0.2
# 122            7.7           2.8            6.7           2.0

# %%
X_train.shape
# Out:
# (100, 4)

# %%
y_train.shape
# Out:
# (100,)

# %%
#DT
from sklearn.tree import DecisionTreeClassifier
tds= DecisionTreeClassifier()
tds.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
#comparision between actual and predicted data
y_predict=tds.predict(X_test)
y_predict
# Out:
# array([1, 0, 2, 1, 1, 0, 1, 2, 1, 1, 2, 0, 0, 0, 0, 1, 2, 1, 1, 2, 0, 2,
#        0, 2, 2, 2, 2, 2, 0, 0, 0, 0, 1, 0, 0, 2, 1, 0, 0, 0, 2, 1, 1, 0,
#        0, 1, 2, 2, 1, 2])

# %%
y_test=np.array(y_test)
y_test
# Out:
# array([1, 0, 2, 1, 1, 0, 1, 2, 1, 1, 2, 0, 0, 0, 0, 1, 2, 1, 1, 2, 0, 2,
#        0, 2, 2, 2, 2, 2, 0, 0, 0, 0, 1, 0, 0, 2, 1, 0, 0, 0, 2, 1, 1, 0,
#        0, 1, 2, 2, 1, 2])

# %%
#checking acuracyScore
from sklearn.metrics import accuracy_score
accuracy_score(y_predict,y_test)
# Out:
# 1.0

# %%
#confusionMatrix
from sklearn.metrics import confusion_matrix
confusion_matrix(y_predict,y_test)
# Out:
# array([[19,  0,  0],
#        [ 0, 15,  0],
#        [ 0,  0, 16]], dtype=int64)

# %%
#classification Reportfor DT model
from sklearn.metrics import classification_report
print(classification_report(y_predict,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        15
#            2       1.00      1.00      1.00        16
#
#     accuracy                           1.00        50
#    macro avg       1.00      1.00      1.00        50
# weighted avg       1.00      1.00      1.00        50

# %%
#DT model visualization
from sklearn import tree
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,17))
dtviz=tree.plot_tree(tds,feature_names=x.columns,filled=True,fontsize=20)

# %%
THANK YOU SO MUCH FOR THIS OPPURTUNITY
